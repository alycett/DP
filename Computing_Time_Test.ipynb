# %%
import cantera as ct
import numpy as np
import time

# %%
# Methane
gas01 = ct.Solution('gri30.yaml')
# Octane
gas02 = ct.Solution('Jerzembeck.yaml')
# Ethanol and Octane
#gas03 = ct.Solution('prf-curran.yaml')
# Ethanol and Octane
gas03 = ct.Solution('Anderlhor.yaml')

# %%
# Methane
start = time.time()
gas01.TPX = 300.0, ct.one_atm, 'CH4:1,O2:2,N2:7.52'
gas01.equilibrate('HP')
stop = time.time()
elapsed_time = stop - start

print('The equilibrate function took', elapsed_time, 'seconds to compute')
print('The equilibirum temperature is', gas01.T, '\n')
# Out:
# The equilibrate function took 0.03628349304199219 seconds to compute
# The equilibirum temperature is 2225.5245834769985

# %%
# Iso-octane, Jerzembeck
start = time.time()
gas02.TPX = 300.0, ct.one_atm, 'IXC8H18:1,O2:12.5,N2:47'
gas02.equilibrate('HP')
stop = time.time()
elapsed_time = stop - start

print('The equilibrate function took', elapsed_time, 'seconds to compute')
print('The equilibirum temperature is', gas02.T, '\n')
# Out:
# The equilibrate function took 0.09632706642150879 seconds to compute
# The equilibirum temperature is 2273.5599391176534

# %%
start = time.time()
frac_oc = 1.0
frac_eth = 0.0
mol_o2 = 8*frac_oc+2*frac_eth + (18*frac_oc+6*frac_eth)/4 - frac_eth/2
gas03.TPX = 300.0, ct.one_atm, {'IXC8H18':frac_oc, 'C2H5OH':frac_eth, 'O2':mol_o2, 'N2':3.76*mol_o2}
gas03.equilibrate('HP')
stop = time.time()
elapsed_time = stop - start

print('The stoichiometric moles of oxygen for a fuel mol fraction of', frac_oc, 'iso-octane and', frac_eth, 'ethanol are', mol_o2)
print('The equilibrate function took', elapsed_time, 'seconds to compute')
print('The equilibirum temperature is', gas03.T, '\n')

start = time.time()
frac_oc = 0.9
frac_eth = 0.1
mol_o2 = 8*frac_oc+2*frac_eth + (18*frac_oc+6*frac_eth)/4 - frac_eth/2
gas03.TPX = 300.0, ct.one_atm, {'IXC8H18':frac_oc, 'C2H5OH':frac_eth, 'O2':mol_o2, 'N2':3.76*mol_o2}
gas03.equilibrate('HP')
stop = time.time()
elapsed_time = stop - start

print('The stoichiometric moles of oxygen for a fuel mol fraction of', frac_oc, 'iso-octane and', frac_eth, 'ethanol are', mol_o2)
print('The equilibrate function took', elapsed_time, 'seconds to compute')
print('The equilibirum temperature is', gas03.T, '\n')

start = time.time()
frac_oc = 0.8
frac_eth = 0.2
mol_o2 = 8*frac_oc+2*frac_eth + (18*frac_oc+6*frac_eth)/4 - frac_eth/2
gas03.TPX = 300.0, ct.one_atm, {'IXC8H18':frac_oc, 'C2H5OH':frac_eth, 'O2':mol_o2, 'N2':3.76*mol_o2}
gas03.equilibrate('HP')
stop = time.time()
elapsed_time = stop - start

print('The stoichiometric moles of oxygen for a fuel mol fraction of', frac_oc, 'iso-octane and', frac_eth, 'ethanol are', mol_o2)
print('The equilibrate function took', elapsed_time, 'seconds to compute')
print('The equilibirum temperature is', gas03.T, '\n')

start = time.time()
frac_oc = 0.7
frac_eth = 0.3
mol_o2 = 8*frac_oc+2*frac_eth + (18*frac_oc+6*frac_eth)/4 - frac_eth/2
gas03.TPX = 300.0, ct.one_atm, {'IXC8H18':frac_oc, 'C2H5OH':frac_eth, 'O2':mol_o2, 'N2':3.76*mol_o2}
gas03.equilibrate('HP')
stop = time.time()
elapsed_time = stop - start

print('The stoichiometric moles of oxygen for a fuel mol fraction of', frac_oc, 'iso-octane and', frac_eth, 'ethanol are', mol_o2)
print('The equilibrate function took', elapsed_time, 'seconds to compute')
print('The equilibirum temperature is', gas03.T, '\n')

start = time.time()
frac_oc = 0.6
frac_eth = 0.4
mol_o2 = 8*frac_oc+2*frac_eth + (18*frac_oc+6*frac_eth)/4 - frac_eth/2
gas03.TPX = 300.0, ct.one_atm, {'IXC8H18':frac_oc, 'C2H5OH':frac_eth, 'O2':mol_o2, 'N2':3.76*mol_o2}
gas03.equilibrate('HP')
stop = time.time()
elapsed_time = stop - start

print('The stoichiometric moles of oxygen for a fuel mol fraction of', frac_oc, 'iso-octane and', frac_eth, 'ethanol are', mol_o2)
print('The equilibrate function took', elapsed_time, 'seconds to compute')
print('The equilibirum temperature is', gas03.T, '\n')

start = time.time()
frac_oc = 0.5
frac_eth = 0.5
mol_o2 = 8*frac_oc+2*frac_eth + (18*frac_oc+6*frac_eth)/4 - frac_eth/2
gas03.TPX = 300.0, ct.one_atm, {'IXC8H18':frac_oc, 'C2H5OH':frac_eth, 'O2':mol_o2, 'N2':3.76*mol_o2}
gas03.equilibrate('HP')
stop = time.time()
elapsed_time = stop - start

print('The stoichiometric moles of oxygen for a fuel mol fraction of', frac_oc, 'iso-octane and', frac_eth, 'ethanol are', mol_o2)
print('The equilibrate function took', elapsed_time, 'seconds to compute')
print('The equilibirum temperature is', gas03.T, '\n')

start = time.time()
frac_oc = 0.4
frac_eth = 0.6
mol_o2 = 8*frac_oc+2*frac_eth + (18*frac_oc+6*frac_eth)/4 - frac_eth/2
gas03.TPX = 300.0, ct.one_atm, {'IXC8H18':frac_oc, 'C2H5OH':frac_eth, 'O2':mol_o2, 'N2':3.76*mol_o2}
gas03.equilibrate('HP')
stop = time.time()
elapsed_time = stop - start

print('The stoichiometric moles of oxygen for a fuel mol fraction of', frac_oc, 'iso-octane and', frac_eth, 'ethanol are', mol_o2)
print('The equilibrate function took', elapsed_time, 'seconds to compute')
print('The equilibirum temperature is', gas03.T, '\n')

start = time.time()
frac_oc = 0.3
frac_eth = 0.7
mol_o2 = 8*frac_oc+2*frac_eth + (18*frac_oc+6*frac_eth)/4 - frac_eth/2
gas03.TPX = 300.0, ct.one_atm, {'IXC8H18':frac_oc, 'C2H5OH':frac_eth, 'O2':mol_o2, 'N2':3.76*mol_o2}
gas03.equilibrate('HP')
stop = time.time()
elapsed_time = stop - start

print('The stoichiometric moles of oxygen for a fuel mol fraction of', frac_oc, 'iso-octane and', frac_eth, 'ethanol are', mol_o2)
print('The equilibrate function took', elapsed_time, 'seconds to compute')
print('The equilibirum temperature is', gas03.T, '\n')

start = time.time()
frac_oc = 0.2
frac_eth = 0.8
mol_o2 = 8*frac_oc+2*frac_eth + (18*frac_oc+6*frac_eth)/4 - frac_eth/2
gas03.TPX = 300.0, ct.one_atm, {'IXC8H18':frac_oc, 'C2H5OH':frac_eth, 'O2':mol_o2, 'N2':3.76*mol_o2}
gas03.equilibrate('HP')
stop = time.time()
elapsed_time = stop - start

print('The stoichiometric moles of oxygen for a fuel mol fraction of', frac_oc, 'iso-octane and', frac_eth, 'ethanol are', mol_o2)
print('The equilibrate function took', elapsed_time, 'seconds to compute')
print('The equilibirum temperature is', gas03.T, '\n')

start = time.time()
frac_oc = 0.1
frac_eth = 0.9
mol_o2 = 8*frac_oc+2*frac_eth + (18*frac_oc+6*frac_eth)/4 - frac_eth/2
gas03.TPX = 300.0, ct.one_atm, {'IXC8H18':frac_oc, 'C2H5OH':frac_eth, 'O2':mol_o2, 'N2':3.76*mol_o2}
gas03.equilibrate('HP')
stop = time.time()
elapsed_time = stop - start

print('The stoichiometric moles of oxygen for a fuel mol fraction of', frac_oc, 'iso-octane and', frac_eth, 'ethanol are', mol_o2)
print('The equilibrate function took', elapsed_time, 'seconds to compute')
print('The equilibirum temperature is', gas03.T, '\n')

start = time.time()
frac_oc = 0
frac_eth = 1
mol_o2 = 8*frac_oc+2*frac_eth + (18*frac_oc+6*frac_eth)/4 - frac_eth/2
gas03.TPX = 300.0, ct.one_atm, {'IXC8H18':frac_oc, 'C2H5OH':frac_eth, 'O2':mol_o2, 'N2':3.76*mol_o2}
gas03.equilibrate('HP')
stop = time.time()
elapsed_time = stop - start

print('The stoichiometric moles of oxygen for a fuel mol fraction of', frac_oc, 'iso-octane and', frac_eth, 'ethanol are', mol_o2)
print('The equilibrate function took', elapsed_time, 'seconds to compute')
print('The equilibirum temperature is', gas03.T, '\n')
# Out:
# The stoichiometric moles of oxygen for a fuel mol fraction of 1.0 iso-octane and 0.0 ethanol are 12.5
# The equilibrate function took 0.8034179210662842 seconds to compute
# The equilibirum temperature is 2273.0047235627358
#
# The stoichiometric moles of oxygen for a fuel mol fraction of 0.9 iso-octane and 0.1 ethanol are 11.55
# The equilibrate function took 0.15937423706054688 seconds to compute
# The equilibirum temperature is 2272.0366035302973
#
# The stoichiometric moles of oxygen for a fuel mol fraction of 0.8 iso-octane and 0.2 ethanol are 10.600000000000001
# The equilibrate function took 0.8070859909057617 seconds to compute
# The equilibirum temperature is 2270.899537436122
#
# The stoichiometric moles of oxygen for a fuel mol fraction of 0.7 iso-octane and 0.3 ethanol are 9.649999999999999
# The equilibrate function took 0.7542963027954102 seconds to compute
# The equilibirum temperature is 2269.5450546998336
#
# ...
